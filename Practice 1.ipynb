# %%
import pyspark

# %%
df=spark.sql("select * from mydata")

# %%
df.show()
df.printSchema()

# %%
df.describe().show()

# %%
df.select('sales').show()

# %%
from pyspark.sql.functions import countDistinct,avg,stddev

# %%
nithi=df.select(avg('sales')).collect()

# %%
ko=nithi[0]
